# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Titulo-Part-1:" data-toc-modified-id="Titulo-Part-1:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Titulo Part 1:</a></span><ul class="toc-item"><li><span><a href="#Clonar-repo-en-colab" data-toc-modified-id="Clonar-repo-en-colab-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Clonar repo en colab</a></span></li><li><span><a href="#Modulos-basicos" data-toc-modified-id="Modulos-basicos-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Modulos basicos</a></span></li><li><span><a href="#Modulos-locales-al-repo" data-toc-modified-id="Modulos-locales-al-repo-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Modulos locales al repo</a></span></li><li><span><a href="#Variables-importantes-del-notebook" data-toc-modified-id="Variables-importantes-del-notebook-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Variables importantes del notebook</a></span></li></ul></li><li><span><a href="#Empezamos-a-manejar-esos-datos" data-toc-modified-id="Empezamos-a-manejar-esos-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Empezamos a manejar esos datos</a></span><ul class="toc-item"><li><span><a href="#Cargar-datos" data-toc-modified-id="Cargar-datos-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Cargar datos</a></span></li><li><span><a href="#Design-matrix-($X$-and-$Y$)" data-toc-modified-id="Design-matrix-($X$-and-$Y$)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Design matrix ($X$ and $Y$)</a></span></li><li><span><a href="#Exploratory-data-analysis-(EDA)" data-toc-modified-id="Exploratory-data-analysis-(EDA)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Exploratory data analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Un-modelo-lineal" data-toc-modified-id="Un-modelo-lineal-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Un modelo lineal</a></span></li></ul></li><li><span><a href="#Como-sabemos-que-nuestro-modelo-es-bueno?" data-toc-modified-id="Como-sabemos-que-nuestro-modelo-es-bueno?-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Como sabemos que nuestro modelo es bueno?</a></span></li><li><span><a href="#Bayesian-Linear-regression" data-toc-modified-id="Bayesian-Linear-regression-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Bayesian Linear regression</a></span></li></ul></li><li><span><a href="#GP-en-proceso" data-toc-modified-id="GP-en-proceso-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>GP en proceso</a></span><ul class="toc-item"><li><span><a href="#Un-GP-es-un-distribucion-de-funciones" data-toc-modified-id="Un-GP-es-un-distribucion-de-funciones-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Un GP es un distribucion de funciones</a></span></li><li><span><a href="#Kerneles" data-toc-modified-id="Kerneles-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Kerneles</a></span></li><li><span><a href="#RBF" data-toc-modified-id="RBF-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>RBF</a></span></li><li><span><a href="#Kerneles-aditivos" data-toc-modified-id="Kerneles-aditivos-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Kerneles aditivos</a></span></li><li><span><a href="#Actividad-explora-kerneles" data-toc-modified-id="Actividad-explora-kerneles-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Actividad explora kerneles</a></span><ul class="toc-item"><li><span><a href="#Tip:-help()-es-tu-amigo!" data-toc-modified-id="Tip:-help()-es-tu-amigo!-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Tip: help() es tu amigo!</a></span></li></ul></li></ul></li><li><span><a href="#GP-en-accion!" data-toc-modified-id="GP-en-accion!-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>GP en accion!</a></span><ul class="toc-item"><li><span><a href="#Vamos-a-optimizar-hiperparametros" data-toc-modified-id="Vamos-a-optimizar-hiperparametros-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Vamos a optimizar hiperparametros</a></span></li><li><span><a href="#Que-estamos-obtimizando?" data-toc-modified-id="Que-estamos-obtimizando?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Que estamos obtimizando?</a></span></li><li><span><a href="#Actividad:" data-toc-modified-id="Actividad:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Actividad:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Titulo Part 1:
#
# Ejecutar este notebook via colab:
# <a href="https://colab.research.google.com/github/riiaa19_workshop_template/blob/master/notebooks/11_Colab_ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Clonar repo en colab

# %%
import os
import subprocess
import sys

GIT_NAME='riiaa19_workshop_template'
GIT_URL='https://riiaa@github.com/riiaa/{}.git'.format(GIT_NAME)
IN_COLAB = 'google.colab' in sys.modules

def run_cmd(cmd):
    print('Output of "{}":'.format(cmd))
    print(subprocess.run(cmd,stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8'))
        
if IN_COLAB:
    SRC_DIR='.'
    run_cmd('rm -rf {}'.format(GIT_NAME))
    run_cmd('git clone --verbose --progress {}'.format(GIT_URL))
    run_cmd('mv {}/* . '.format(GIT_NAME))
    run_cmd('rm -rf {}'.format(GIT_NAME))
    run_cm('pip install pymc3')
    run_cm('pip install arviz')
else:
    SRC_DIR='..'
    
print('Using colab? {}, using root directory "{}"'.format(IN_COLAB,SRC_DIR))
# Out:
# Using colab? False, using root directory ".."

# %% [markdown]
# ## Modulos basicos

# %%
import os
import sys
from tqdm.autonotebook import tqdm
from ipywidgets import interact
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sc
import seaborn as sns
import sklearn
import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow_probability as tfp
# Alias de ayuda

tfd = tfp.distributions
psd_kernels = tfp.positive_semidefinite_kernels

print('tf :',tf.__version__)
print('tf.keras :',tfk.__version__)
print('tfp:',tfp.__version__)
# Out:
# tf : 2.0.0-dev20190708
# tf.keras : 2.2.4-tf
# tfp: 0.7.0

# %% [markdown]
# ## Modulos locales al repo

# %%
sys.path.append(os.path.join(SRC_DIR,'code'))
import utils

# %% [markdown]
# ## Variables importantes del notebook

# %%
data_path = os.path.join(SRC_DIR,'data')

# %% [markdown]
# # Empezamos a manejar esos datos
# ## Cargar datos

# %%
df = pd.read_csv(os.path.join(data_path,'mauna_launa_co2.csv'))
print(df.shape)
df.head()
# Out:
# (731, 2)
#         Date     CO2
# 0  1958.2027  315.70
# 1  1958.2877  317.45
# 2  1958.3699  317.51
# 3  1958.5370  315.86
# 4  1958.6219  314.93

# %% [markdown]
# ## Design matrix ($X$ and $Y$)

# %%
x_raw = df['Date'].values.reshape(-1,1)
y_raw = df['CO2'].values.reshape(-1,1)
print(x_raw.shape,y_raw.shape)
n_data =len(x_raw)
# Out:
# (731, 1) (731, 1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

n_train = int(n_data*0.80)
x_scaler = StandardScaler().fit(x_raw)
y_scaler = StandardScaler().fit(y_raw)

x = x_scaler.transform(x_raw)
y = y_scaler.transform(y_raw)

x_train,x_test,y_train,y_test = x[:n_train],x[n_train:], y[:n_train],y[n_train:]
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (584, 1) (147, 1) (584, 1) (147, 1)

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %%
plt.scatter(x_train,y_train,s=1,label='train')
plt.scatter(x_test,y_test,s=1,label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### Un modelo lineal

# %%
negloglik = lambda y, p_y: -p_y.log_prob(y)
# Modelo
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1),
  tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t, scale=1)),
])
# Inferencia (entrenar con datos)
model.compile(optimizer=tf.optimizers.SGD(learning_rate=0.05), loss=negloglik)
model.fit(x_train, y_train, batch_size=len(x_train), epochs=500)

y_pred_dist = model(x_test)
print(y_pred.shape)
# Out:
# Train on 584 samples
# Epoch 1/500
# 584/584 [==============================] - 0s 31us/sample - loss: 0.9637
# Epoch 2/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9608
# Epoch 3/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9582
# Epoch 4/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9559
# Epoch 5/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9537
# Epoch 6/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9517
# Epoch 7/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9499
# Epoch 8/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9482
# Epoch 9/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9467
# Epoch 10/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9453
# Epoch 11/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9440
# Epoch 12/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9428
# Epoch 13/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9417
# Epoch 14/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9406
# Epoch 15/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9397
# Epoch 16/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9388
# Epoch 17/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9380
# Epoch 18/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9372
# Epoch 19/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9365
# Epoch 20/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9358
# Epoch 21/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9352
# Epoch 22/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9346
# Epoch 23/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9340
# Epoch 24/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9335
# Epoch 25/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9330
# Epoch 26/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9326
# Epoch 27/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9322
# Epoch 28/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9318
# Epoch 29/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9314
# Epoch 30/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9310
# Epoch 31/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9307
# Epoch 32/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9304
# Epoch 33/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9301
# Epoch 34/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9298
# Epoch 35/500
# 584/584 [==============================] - 0s 6us/sample - loss: 0.9296
# Epoch 36/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9293
# Epoch 37/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9291
# Epoch 38/500
# 584/584 [==============================] - 0s 6us/sample - loss: 0.9289
# Epoch 39/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9287
# Epoch 40/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9285
# Epoch 41/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9283
# Epoch 42/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9281
# Epoch 43/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9279
# Epoch 44/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9278
# Epoch 45/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9276
# Epoch 46/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9275
# Epoch 47/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9274
# Epoch 48/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9272
# Epoch 49/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9271
# Epoch 50/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9270
# Epoch 51/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9269
# Epoch 52/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9268
# Epoch 53/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9267
# Epoch 54/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9266
# Epoch 55/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9265
# Epoch 56/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9264
# Epoch 57/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9264
# Epoch 58/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9263
# Epoch 59/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9262
# Epoch 60/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9262
# Epoch 61/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9261
# Epoch 62/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9260
# Epoch 63/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9260
# Epoch 64/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9259
# Epoch 65/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9259
# Epoch 66/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9258
# Epoch 67/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9258
# Epoch 68/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9257
# Epoch 69/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9257
# Epoch 70/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9256
# Epoch 71/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9256
# Epoch 72/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9256
# Epoch 73/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9255
# Epoch 74/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9255
# Epoch 75/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9255
# Epoch 76/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9255
# Epoch 77/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9254
# Epoch 78/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9254
# Epoch 79/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9254
# Epoch 80/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9254
# Epoch 81/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9253
# Epoch 82/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9253
# Epoch 83/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9253
# Epoch 84/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9253
# Epoch 85/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9253
# Epoch 86/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9252
# Epoch 87/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9252
# Epoch 88/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9252
# Epoch 89/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9252
# Epoch 90/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9252
# Epoch 91/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9252
# Epoch 92/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9251
# Epoch 93/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9251
# Epoch 94/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9251
# Epoch 95/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9251
# Epoch 96/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9251
# Epoch 97/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9251
# Epoch 98/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9251
# Epoch 99/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9251
# Epoch 100/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9251
# Epoch 101/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9251
# Epoch 102/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9251
# Epoch 103/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 104/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 105/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 106/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 107/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 108/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 109/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 110/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 111/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 112/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 113/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 114/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 115/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 116/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 117/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 118/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 119/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 120/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 121/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9250
# Epoch 122/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 123/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 124/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 125/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 126/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 127/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9250
# Epoch 128/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9250
# Epoch 129/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 130/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 131/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 132/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 133/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 134/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 135/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 136/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 137/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 138/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 139/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 140/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 141/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 142/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 143/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 144/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 145/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 146/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 147/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 148/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 149/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 150/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 151/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 152/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 153/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 154/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 155/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 156/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 157/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 158/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 159/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 160/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 161/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 162/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 163/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 164/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 165/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 166/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 167/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 168/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 169/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 170/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 171/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 172/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 173/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 174/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 175/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 176/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 177/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 178/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 179/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 180/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 181/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 182/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 183/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 184/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 185/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 186/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 187/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 188/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 189/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 190/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 191/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 192/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 193/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 194/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 195/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 196/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 197/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 198/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 199/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 200/500
# 584/584 [==============================] - 0s 6us/sample - loss: 0.9249
# Epoch 201/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 202/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 203/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 204/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 205/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 206/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 207/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 208/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 209/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 210/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 211/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 212/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 213/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 214/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 215/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 216/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 217/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 218/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 219/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 220/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 221/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 222/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 223/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 224/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 225/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 226/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 227/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 228/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 229/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 230/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 231/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 232/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 233/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 234/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 235/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 236/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 237/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 238/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 239/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 240/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 241/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 242/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 243/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 244/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 245/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 246/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 247/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 248/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 249/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 250/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 251/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 252/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 253/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 254/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 255/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 256/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 257/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 258/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 259/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 260/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 261/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 262/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 263/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 264/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 265/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 266/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 267/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 268/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 269/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 270/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 271/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 272/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 273/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 274/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 275/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 276/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 277/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 278/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 279/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 280/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 281/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 282/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 283/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 284/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 285/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 286/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 287/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 288/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 289/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 290/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 291/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 292/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 293/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 294/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 295/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 296/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 297/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 298/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 299/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 300/500
# 584/584 [==============================] - 0s 7us/sample - loss: 0.9249
# Epoch 301/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 302/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 303/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 304/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 305/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 306/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 307/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 308/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 309/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 310/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 311/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 312/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 313/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9249
# Epoch 314/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 315/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 316/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 317/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 318/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 319/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 320/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 321/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 322/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 323/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 324/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 325/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 326/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 327/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 328/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 329/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 330/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 331/500
# 584/584 [==============================] - 0s 18us/sample - loss: 0.9249
# Epoch 332/500
# 584/584 [==============================] - 0s 27us/sample - loss: 0.9249
# Epoch 333/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 334/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 335/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 336/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 337/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 338/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 339/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 340/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 341/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 342/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 343/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 344/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 345/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 346/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 347/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 348/500
# 584/584 [==============================] - 0s 7us/sample - loss: 0.9249
# Epoch 349/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 350/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 351/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 352/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 353/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 354/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 355/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 356/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 357/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 358/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 359/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 360/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 361/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 362/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 363/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 364/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 365/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 366/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 367/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 368/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 369/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 370/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 371/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 372/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 373/500
# 584/584 [==============================] - 0s 6us/sample - loss: 0.9249
# Epoch 374/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 375/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 376/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 377/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 378/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 379/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 380/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 381/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 382/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 383/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 384/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 385/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 386/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 387/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 388/500
# 584/584 [==============================] - 0s 8us/sample - loss: 0.9249
# Epoch 389/500
# 584/584 [==============================] - 0s 9us/sample - loss: 0.9249
# Epoch 390/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 391/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 392/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 393/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 394/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 395/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 396/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 397/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 398/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 399/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 400/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 401/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 402/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 403/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 404/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 405/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 406/500
# 584/584 [==============================] - 0s 6us/sample - loss: 0.9249
# Epoch 407/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 408/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 409/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 410/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 411/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 412/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 413/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 414/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 415/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 416/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 417/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 418/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 419/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 420/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 421/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 422/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 423/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 424/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 425/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 426/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 427/500
# 584/584 [==============================] - 0s 5us/sample - loss: 0.9249
# Epoch 428/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 429/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 430/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 431/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 432/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 433/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 434/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 435/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 436/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 437/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 438/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 439/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 440/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 441/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 442/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 443/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 444/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 445/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 446/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 447/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 448/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 449/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 450/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 451/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 452/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 453/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 454/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 455/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 456/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 457/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 458/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 459/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 460/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 461/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 462/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 463/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 464/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 465/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 466/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 467/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 468/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 469/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 470/500
# 584/584 [==============================] - 0s 4us/sample - loss: 0.9249
# Epoch 471/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 472/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 473/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 474/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 475/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 476/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 477/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 478/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 479/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 480/500
# 584/584 [==============================] - 0s 6us/sample - loss: 0.9249
# Epoch 481/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 482/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 483/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 484/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 485/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 486/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 487/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 488/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 489/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 490/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 491/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 492/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 493/500
# 584/584 [==============================] - 0s 1us/sample - loss: 0.9249
# Epoch 494/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 495/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 496/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 497/500
# 584/584 [==============================] - 0s 2us/sample - loss: 0.9249
# Epoch 498/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 499/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# Epoch 500/500
# 584/584 [==============================] - 0s 3us/sample - loss: 0.9249
# (147, 1)

# %%
print('alpha:',model.layers[0].weights[0].numpy())
print('beta:',model.layers[0].weights[1].numpy())
# Out:
# alpha: [[0.8852224]]
# beta: [-0.07105669]

# %%
y_pred = y_pred_dist.mean().numpy()
plt.plot(x_train,y_train,label='data')
plt.plot(x_test,y_pred,label='linear regression')
plt.ylabel('CO2 scaled')
plt.xlabel('time scaled')
plt.legend()
plt.show()

# %% [markdown]
# ## Como sabemos que nuestro modelo es bueno?

# %%
from sklearn.metrics import r2_score, mean_squared_error

print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# -0.5285217782885234
# 0.14629793241806088

# %% [markdown]
# ## Bayesian Linear regression

# %%
import pymc3 as pm
print('PyMC3:',pm.__version__)
# Out:
# PyMC3: 3.7

# %%
bayes_linreg = pm.Model()

with bayes_linreg:

    # Prior
    alpha = pm.Normal('alpha', mu=0, sigma=10)
    beta = pm.Normal('beta', mu=0, sigma=10)
    sigma = pm.HalfNormal('sigma', sigma=1)

    # Valor esperado
    mu = alpha + beta*x
    lm = lambda x, sample: sample['alpha'] + sample['beta']* x
    # Likelihood
    y_obs = pm.Normal('Y_obs', mu=mu, sigma=sigma, observed=y)

    # Samplear del posterior
    trace = pm.sample(50)
# Out:
# W0828 08:57:15.629882 140586609346368 sampling.py:383] Only 50 samples in chain.
# Sampling 4 chains: 100%|██████████| 2200/2200 [00:00<00:00, 2249.38draws/s]
# /home/beangoben/anaconda3/lib/python3.7/site-packages/pymc3/sampling.py:464: UserWarning: The number of samples is too small to check convergence reliably.
#   warnings.warn("The number of samples is too small to check convergence reliably.")

# %%
pm.traceplot(trace)
plt.show()

# %%
pm.summary(trace)
# Out:
#            mean        sd  mc_error   hpd_2.5  hpd_97.5       n_eff      Rhat
# alpha -0.000196  0.005918  0.000427 -0.011829  0.011491  211.011401  0.993560
# beta   0.988192  0.005012  0.000302  0.978608  0.997542  487.325227  0.996822
# sigma  0.153179  0.004020  0.000250  0.145092  0.160576  376.717431  1.010465

# %%
pm.plot_posterior(trace)
plt.show()

# %%
plt.plot(x,y)
pm.plot_posterior_predictive_glm(trace,eval=x_test,lm=lm, samples=10)
plt.show()

# %% [markdown]
# # GP en proceso

# %%
n_train =100

x_grid = np.expand_dims(np.linspace(-1., 1., n_train), -1).astype(np.float32)
print(x_grid.shape)

kernel = psd_kernels.ExponentiatedQuadratic(amplitude=1.0)
gp = tfd.GaussianProcess(kernel, x_grid)
gp
# Out:
# (100, 1)
# <tfp.distributions.GaussianProcess 'GaussianProcess/' batch_shape=[] event_shape=[100] dtype=float32>

# %% [markdown]
# ## Un GP es un distribucion de funciones

# %%
n=100
y_grid = gp.sample(n).numpy().T
plt.plot(x_grid, y_grid,alpha=0.25)
y_mean = gp.mean().numpy().T
y_std = gp.stddev().numpy().T
plt.plot(x_grid, y_mean,label='mean')
plt.fill_between(x_grid.flatten(),y_mean-2*y_std,y_mean+2*y_std,alpha=0.2,label='1-$sigma$')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Kerneles
#
# Primero a ver nuestro menu de kernels presionando **tab** en la celda:

# %%
psd_kernels.
# Out:
#   File "<ipython-input-159-301a80f7165a>", line 1
#     psd_kernels.
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## RBF
#
# $$
# K(x_i,x_j) = A e^{-\frac{\|x_i-x_j\|^2}{l}}
# $$

# %%
kernel = psd_kernels.ExponentiatedQuadratic(amplitude=1.0,length_scale=1.0)
K = np.zeros((n_train,n_train))
for i, xi in enumerate(x_grid):
    K[i] = kernel.apply(xi,x_grid)
print(K.shape)
plt.imshow(K)
plt.show()

K = np.zeros((n_train,n_train))
for i, xi in enumerate(x_grid):
    for j, xj in enumerate(x_grid):
        K[i,j] = kernel.apply(xi,xj)
print(K.shape)
plt.imshow(K)
plt.show()

K = kernel.matrix(x_grid,x_grid)
plt.imshow(K)
plt.show()
# Out:
# (100, 100)
# (100, 100)

# %%
for i in range(0,n_train,20):
    plt.plot(K[i,:],label='K[{}]'.format(i))
plt.legend()
plt.show()

# %%
def plot_kernel_imshow(amplitude=1.0,length_scale=1.0):
    amp = 10**amplitude
    ls = 10**length_scale
    kernel = psd_kernels.ExponentiatedQuadratic(amplitude=amp,
                                                length_scale=ls)
    K = kernel.matrix(x_grid,x_grid)
    plt.title('A={:.2e},l={:.2e}'.format(amp,ls))
    plt.imshow(K)
    plt.colorbar()

interact(plot_kernel_imshow,amplitude=(-2,2,0.1),length_scale=(-2,2,0.1))
# Out:
# interactive(children=(FloatSlider(value=1.0, description='amplitude', max=2.0, min=-2.0), FloatSlider(value=1.…
# <function __main__.plot_kernel_imshow(amplitude=1.0, length_scale=1.0)>

# %%
def plot_kernel_lines(amplitude=0.0,length_scale=0.0):
    amp = 10**amplitude
    ls = 10**length_scale
    kernel = psd_kernels.ExponentiatedQuadratic(amplitude=amp,
                                                length_scale=ls)
    for i in range(0,len(x_grid),20):
        k_x  = kernel.apply(x_grid[i],x_grid)
        plt.plot(x_grid, k_x,label='K[{}]'.format(i))
    plt.ylim([0,10])
    plt.legend()
interact(plot_kernel_lines,amplitude=(-1,1,0.1),length_scale=(-3.0,1,0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='amplitude', max=1.0, min=-1.0), FloatSlider(value=0.…
# <function __main__.plot_kernel_lines(amplitude=0.0, length_scale=0.0)>

# %% [markdown]
# ## Kerneles aditivos

# %%
k1 = psd_kernels.ExponentiatedQuadratic(amplitude=1.0,length_scale=1.0)
k2 = psd_kernels.MaternFiveHalves(amplitude=1.0,length_scale=1.0)
kernel = k1+k2
kernel
# Out:
# <tfp.positive_semidefinite_kernels._SumKernel 'SumKernel' batch_shape=() feature_ndims=1 dtype=float32>

# %%
plt.plot(x_grid, kernel.apply(0.0,x_grid),label='k')
plt.plot(x_grid, k1.apply(0.0,x_grid),label='k1')
plt.plot(x_grid, k2.apply(0.0,x_grid),label='k2')
plt.legend()
plt.show()

# %%
k1 = psd_kernels.ExponentiatedQuadratic(amplitude=1.0,length_scale=1.0)
k2 = psd_kernels.MaternFiveHalves(amplitude=1.0,length_scale=1.0)
kernel = k1*k2
plt.plot(x_grid, kernel.apply(0.0,x_grid),label='k')
plt.plot(x_grid, k1.apply(0.0,x_grid),label='k1')
plt.plot(x_grid, k2.apply(0.0,x_grid),label='k2')
plt.legend()
plt.show()

# %% [markdown]
# ## Actividad explora kerneles
# ### Tip: help() es tu amigo!
#
# Prueba los siguientes kerneles, explora su parametros, que significan?
#
# * ExpSinSquared
# * MaternFiveHalves
# * RationalQuadratic
# * Linear
#
# Para cada kernel:
#
# 1. Identifica sus parametros
# 2. Crea plots 1d de k(x,x_i) y 2d de K
# 3. Interpreta los parametros
#
# Recomendado, anota tus observaciones en una table:

# %%
help(psd_kernels.ExponentiatedQuadratic)
# Out:
# Help on class ExponentiatedQuadratic in module tensorflow_probability.python.positive_semidefinite_kernels.exponentiated_quadratic:
#
# class ExponentiatedQuadratic(tensorflow_probability.python.positive_semidefinite_kernels.positive_semidefinite_kernel.PositiveSemidefiniteKernel)
#  |  ExponentiatedQuadratic(amplitude=None, length_scale=None, feature_ndims=1, validate_args=False, name='ExponentiatedQuadratic')
#  |
#  |  The ExponentiatedQuadratic kernel.
#  |
#  |  Sometimes called the "squared exponential", "Gaussian" or "radial basis
#  |  function", this kernel function has the form
#  |
#  |    ```none
#  |    k(x, y) = amplitude**2 * exp(-||x - y||**2 / (2 * length_scale**2))
#  |    ```
#  |
#  |  where the double-bars represent vector length (ie, Euclidean, or L2 norm).
#  |
#  |  Method resolution order:
#  |      ExponentiatedQuadratic
#  |      tensorflow_probability.python.positive_semidefinite_kernels.positive_semidefinite_kernel.PositiveSemidefiniteKernel
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, amplitude=None, length_scale=None, feature_ndims=1, validate_args=False, name='ExponentiatedQuadratic')
#  |      Construct an ExponentiatedQuadratic kernel instance.
#  |
#  |      Args:
#  |        amplitude: floating point `Tensor` that controls the maximum value
#  |          of the kernel. Must be broadcastable with `length_scale` and inputs to
#  |          `apply` and `matrix` methods. Must be greater than zero.
#  |        length_scale: floating point `Tensor` that controls how sharp or wide the
#  |          kernel shape is. This provides a characteristic "unit" of length against
#  |          which `||x - y||` can be compared for scale. Must be broadcastable with
#  |          `amplitude` and inputs to `apply` and `matrix` methods.
#  |        feature_ndims: Python `int` number of rightmost dims to include in the
#  |          squared difference norm in the exponential.
#  |        validate_args: If `True`, parameters are checked for validity despite
#  |          possibly degrading runtime performance
#  |        name: Python `str` name prefixed to Ops created by this class.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  amplitude
#  |      Amplitude parameter.
#  |
#  |  length_scale
#  |      Length scale parameter.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from tensorflow_probability.python.positive_semidefinite_kernels.positive_semidefinite_kernel.PositiveSemidefiniteKernel:
#  |
#  |  __add__(self, k)
#  |
#  |  __iadd__(self, k)
#  |
#  |  __imul__(self, k)
#  |
#  |  __mul__(self, k)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  apply(self, x1, x2)
#  |      Apply the kernel function to a pair of (batches of) inputs.
#  |
#  |      Args:
#  |        x1: `Tensor` input to the first positional parameter of the kernel, of
#  |          shape `[b1, ..., bB, f1, ..., fF]`, where `B` may be zero (ie, no
#  |          batching) and `F` (number of feature dimensions) must equal the kernel's
#  |          `feature_ndims` property. Batch shape must broadcast with the batch
#  |          shape of `x2` and with the kernel's parameters.
#  |        x2: `Tensor` input to the second positional parameter of the kernel,
#  |          shape `[c1, ..., cC, f1, ..., fF]`, where `C` may be zero (ie, no
#  |          batching) and `F` (number of feature dimensions) must equal the kernel's
#  |          `feature_ndims` property. Batch shape must broadcast with the batch
#  |          shape of `x1` and with the kernel's parameters.
#  |
#  |      Returns:
#  |        `Tensor` containing the (batch of) results of applying the kernel function
#  |        to inputs `x1` and `x2`. If the kernel parameters' batch shape is
#  |        `[k1, ..., kK]` then the shape of the `Tensor` resulting from this method
#  |        call is `broadcast([b1, ..., bB], [c1, ..., cC], [k1, ..., kK])`.
#  |
#  |      Given an index set `S`, a kernel function is mathematically defined as a
#  |      real- or complex-valued function on `S` satisfying the
#  |      positive semi-definiteness constraint:
#  |
#  |      ```none
#  |      sum_i sum_j (c[i]*) c[j] k(x[i], x[j]) >= 0
#  |      ```
#  |
#  |      for any finite collections `{x[1], ..., x[N]}` in `S` and
#  |      `{c[1], ..., c[N]}` in the reals (or the complex plane). '*' is the complex
#  |      conjugate, in the complex case.
#  |
#  |      This method most closely resembles the function described in the
#  |      mathematical definition of a kernel. Given a PositiveSemidefiniteKernel `k`
#  |      with scalar parameters and inputs `x` and `y` in `S`, `apply(x, y)` yields a
#  |      single scalar value. Given the same kernel and, say, batched inputs of shape
#  |      `[b1, ..., bB, f1, ..., fF]`, it will yield a batch of scalars of shape
#  |      `[b1, ..., bB]`.
#  |
#  |      #### Examples
#  |
#  |      ```python
#  |      import tensorflow_probability as tfp
#  |
#  |      # Suppose `SomeKernel` acts on vectors (rank-1 tensors)
#  |      scalar_kernel = tfp.positive_semidefinite_kernels.SomeKernel(param=.5)
#  |      scalar_kernel.batch_shape
#  |      # ==> []
#  |
#  |      # `x` and `y` are batches of five 3-D vectors:
#  |      x = np.ones([5, 3], np.float32)
#  |      y = np.ones([5, 3], np.float32)
#  |      scalar_kernel.apply(x, y).shape
#  |      # ==> [5]
#  |      ```
#  |
#  |      The above output is the result of vectorized computation of the five values
#  |
#  |      ```none
#  |      [k(x[0], y[0]), k(x[1], y[1]), ..., k(x[4], y[4])]
#  |      ```
#  |
#  |      Now we can consider a kernel with batched parameters:
#  |
#  |      ```python
#  |      batch_kernel = tfp.positive_semidefinite_kernels.SomeKernel(param=[.2, .5])
#  |      batch_kernel.batch_shape
#  |      # ==> [2]
#  |      batch_kernel.apply(x, y).shape
#  |      # ==> Error! [2] and [5] can't broadcast.
#  |      ```
#  |
#  |      The parameter batch shape of `[2]` and the input batch shape of `[5]` can't
#  |      be broadcast together. We can fix this by giving the parameter a shape of
#  |      `[2, 1]` which will correctly broadcast with `[5]` to yield `[2, 5]`:
#  |
#  |      ```python
#  |      batch_kernel = tfp.positive_semidefinite_kernels.SomeKernel(
#  |          param=[[.2], [.5]])
#  |      batch_kernel.batch_shape
#  |      # ==> [2, 1]
#  |      batch_kernel.apply(x, y).shape
#  |      # ==> [2, 5]
#  |      ```
#  |
#  |  batch_shape_tensor(self)
#  |      The batch_shape property of a PositiveSemidefiniteKernel as a `Tensor`.
#  |
#  |      Returns:
#  |          `Tensor` which evaluates to a vector of integers which are the
#  |          fully-broadcast shapes of the kernel parameters.
#  |
#  |  matrix(self, x1, x2)
#  |      Construct (batched) matrices from (batches of) collections of inputs.
#  |
#  |      Args:
#  |        x1: `Tensor` input to the first positional parameter of the kernel, of
#  |          shape `[b1, ..., bB, e1, f1, ..., fF]`, where `B` may be zero (ie, no
#  |          batching), e1 is an integer greater than zero, and `F` (number of
#  |          feature dimensions) must equal the kernel's `feature_ndims` property.
#  |          Batch shape must broadcast with the batch shape of `x2` and with the
#  |          kernel's parameters *after* parameter expansion (see
#  |          `param_expansion_ndims` argument).
#  |        x2: `Tensor` input to the second positional parameter of the kernel,
#  |          shape `[c1, ..., cC, e2, f1, ..., fF]`, where `C` may be zero (ie, no
#  |          batching), e2 is an integer greater than zero,  and `F` (number of
#  |          feature dimensions) must equal the kernel's `feature_ndims` property.
#  |          Batch shape must broadcast with the batch shape of `x1` and with the
#  |          kernel's parameters *after* parameter expansion (see
#  |          `param_expansion_ndims` argument).
#  |
#  |      Returns:
#  |        `Tensor containing (batch of) matrices of kernel applications to pairs
#  |        from inputs `x1` and `x2`. If the kernel parameters' batch shape is
#  |        `[k1, ..., kK]`, then the shape of the resulting `Tensor` is
#  |        `broadcast([b1, ..., bB], [c1, ..., cC], [k1, ..., kK]) + [e1, e2]`.
#  |
#  |      Given inputs `x1` and `x2` of shapes
#  |
#  |      ```none
#  |      [b1, ..., bB, e1, f1, ..., fF]
#  |      ```
#  |
#  |      and
#  |
#  |      ```none
#  |      [c1, ..., cC, e2, f1, ..., fF]
#  |      ```
#  |
#  |      This method computes the batch of `e1 x e2` matrices resulting from applying
#  |      the kernel function to all pairs of inputs from `x1` and `x2`. The shape
#  |      of the batch of matrices is the result of broadcasting the batch shapes of
#  |      `x1`, `x2`, and the kernel parameters (see examples below). As such, it's
#  |      required that these shapes all be broadcast compatible. However, the kernel
#  |      parameter batch shapes need not broadcast against the 'example shapes' (`e1`
#  |      and `e2` above).
#  |
#  |      When the two inputs are the (batches of) identical collections, the
#  |      resulting matrix is the so-called Gram (or Gramian) matrix
#  |      (https://en.wikipedia.org/wiki/Gramian_matrix).
#  |
#  |      N.B., this method can only be used to compute the pairwise application of
#  |      the kernel function on rank-1 collections. E.g., it *does* support inputs of
#  |      shape `[e1, f]` and `[e2, f]`, yielding a matrix of shape `[e1, e2]`. It
#  |      *does not* support inputs of shape `[e1, e2, f]` and `[e3, e4, f]`, yielding
#  |      a `Tensor` of shape `[e1, e2, e3, e4]`. To do this, one should instead
#  |      reshape the inputs and pass them to `apply`, e.g.:
#  |
#  |      ```python
#  |      k = tfpk.SomeKernel()
#  |      t1 = tf.placeholder([4, 4, 3], tf.float32)
#  |      t2 = tf.placeholder([5, 5, 3], tf.float32)
#  |      k.apply(
#  |          tf.reshape(t1, [4, 4, 1, 1, 3]),
#  |          tf.reshape(t2, [1, 1, 5, 5, 3])).shape
#  |      # ==> [4, 4, 5, 5, 3]
#  |      ```
#  |
#  |      `matrix` is a special case of the above, where there is only one example
#  |      dimension; indeed, its implementation looks almost exactly like the above
#  |      (reshaped inputs passed to the private version of `_apply`).
#  |
#  |      #### Examples
#  |
#  |      First, consider a kernel with a single scalar parameter.
#  |
#  |      ```python
#  |      import tensorflow_probability as tfp
#  |
#  |      scalar_kernel = tfp.positive_semidefinite_kernels.SomeKernel(param=.5)
#  |      scalar_kernel.batch_shape
#  |      # ==> []
#  |
#  |      # Our inputs are two lists of 3-D vectors
#  |      x = np.ones([5, 3], np.float32)
#  |      y = np.ones([4, 3], np.float32)
#  |      scalar_kernel.matrix(x, y).shape
#  |      # ==> [5, 4]
#  |      ```
#  |
#  |      The result comes from applying the kernel to the entries in `x` and `y`
#  |      pairwise, across all pairs:
#  |
#  |        ```none
#  |        | k(x[0], y[0])    k(x[0], y[1])  ...  k(x[0], y[3]) |
#  |        | k(x[1], y[0])    k(x[1], y[1])  ...  k(x[1], y[3]) |
#  |        |      ...              ...                 ...      |
#  |        | k(x[4], y[0])    k(x[4], y[1])  ...  k(x[4], y[3]) |
#  |        ```
#  |
#  |      Now consider a kernel with batched parameters with the same inputs
#  |
#  |      ```python
#  |      batch_kernel = tfp.positive_semidefinite_kernels.SomeKernel(param=[1., .5])
#  |      batch_kernel.batch_shape
#  |      # ==> [2]
#  |
#  |      batch_kernel.matrix(x, y).shape
#  |      # ==> [2, 5, 4]
#  |      ```
#  |
#  |      This results in a batch of 2 matrices, one computed from the kernel with
#  |      `param = 1.` and the other with `param = .5`.
#  |
#  |      We also support batching of the inputs. First, let's look at that with
#  |      the scalar kernel again.
#  |
#  |      ```python
#  |      # Batch of 10 lists of 5 vectors of dimension 3
#  |      x = np.ones([10, 5, 3], np.float32)
#  |
#  |      # Batch of 10 lists of 4 vectors of dimension 3
#  |      y = np.ones([10, 4, 3], np.float32)
#  |
#  |      scalar_kernel.matrix(x, y).shape
#  |      # ==> [10, 5, 4]
#  |      ```
#  |
#  |      The result is a batch of 10 matrices built from the batch of 10 lists of
#  |      input vectors. These batch shapes have to be broadcastable. The following
#  |      will *not* work:
#  |
#  |      ```python
#  |      x = np.ones([10, 5, 3], np.float32)
#  |      y = np.ones([20, 4, 3], np.float32)
#  |      scalar_kernel.matrix(x, y).shape
#  |      # ==> Error! [10] and [20] can't broadcast.
#  |      ```
#  |
#  |      Now let's consider batches of inputs in conjunction with batches of kernel
#  |      parameters. We require that the input batch shapes be broadcastable with
#  |      the kernel parameter batch shapes, otherwise we get an error:
#  |
#  |      ```python
#  |      x = np.ones([10, 5, 3], np.float32)
#  |      y = np.ones([10, 4, 3], np.float32)
#  |
#  |      batch_kernel = tfp.positive_semidefinite_kernels.SomeKernel(params=[1., .5])
#  |      batch_kernel.batch_shape
#  |      # ==> [2]
#  |      batch_kernel.matrix(x, y).shape
#  |      # ==> Error! [2] and [10] can't broadcast.
#  |      ```
#  |
#  |      The fix is to make the kernel parameter shape broadcastable with `[10]` (or
#  |      reshape the inputs to be broadcastable!):
#  |
#  |      ```python
#  |      x = np.ones([10, 5, 3], np.float32)
#  |      y = np.ones([10, 4, 3], np.float32)
#  |
#  |      batch_kernel = tfp.positive_semidefinite_kernels.SomeKernel(
#  |          params=[[1.], [.5]])
#  |      batch_kernel.batch_shape
#  |      # ==> [2, 1]
#  |      batch_kernel.matrix(x, y).shape
#  |      # ==> [2, 10, 5, 4]
#  |
#  |      # Or, make the inputs broadcastable:
#  |      x = np.ones([10, 1, 5, 3], np.float32)
#  |      y = np.ones([10, 1, 4, 3], np.float32)
#  |
#  |      batch_kernel = tfp.positive_semidefinite_kernels.SomeKernel(
#  |          params=[1., .5])
#  |      batch_kernel.batch_shape
#  |      # ==> [2]
#  |      batch_kernel.matrix(x, y).shape
#  |      # ==> [10, 2, 5, 4]
#  |
#  |      ```
#  |
#  |      Here, we have the result of applying the kernel, with 2 different
#  |      parameters, to each of a batch of 10 pairs of input lists.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from tensorflow_probability.python.positive_semidefinite_kernels.positive_semidefinite_kernel.PositiveSemidefiniteKernel:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  batch_shape
#  |      The batch_shape property of a PositiveSemidefiniteKernel.
#  |
#  |      This property describes the fully broadcast shape of all kernel parameters.
#  |      For example, consider an ExponentiatedQuadratic kernel, which is
#  |      parameterized by an amplitude and length_scale:
#  |
#  |      ```none
#  |      exp_quad(x, x') := amplitude * exp(||x - x'||**2 / length_scale**2)
#  |      ```
#  |
#  |      The batch_shape of such a kernel is derived from broadcasting the shapes of
#  |      `amplitude` and `length_scale`. E.g., if their shapes were
#  |
#  |      ```python
#  |      amplitude.shape = [2, 1, 1]
#  |      length_scale.shape = [1, 4, 3]
#  |      ```
#  |
#  |      then `exp_quad`'s batch_shape would be `[2, 4, 3]`.
#  |
#  |      Note that this property defers to the private _batch_shape method, which
#  |      concrete implementation sub-classes are obliged to provide.
#  |
#  |      Returns:
#  |          `TensorShape` instance describing the fully broadcast shape of all
#  |          kernel parameters.
#  |
#  |  dtype
#  |      DType over which the kernel operates.
#  |
#  |  feature_ndims
#  |      The number of feature dimensions.
#  |
#  |      Kernel functions generally act on pairs of inputs from some space like
#  |
#  |      ```none
#  |      R^(d1 x ... x  dD)
#  |      ```
#  |
#  |      or, in words: rank-`D` real-valued tensors of shape `[d1, ..., dD]`. Inputs
#  |      can be vectors in some `R^N`, but are not restricted to be. Indeed, one
#  |      might consider kernels over matrices, tensors, or even more general spaces,
#  |      like strings or graphs.
#  |
#  |      Returns:
#  |        The number of feature dimensions (feature rank) of this kernel.
#  |
#  |  name
#  |      Name prepended to all ops created by this class.

# %% [markdown]
# # GP en accion!
#
# ## Vamos a optimizar hiperparametros
#
# Primero un modelo:

# %%
x_train.shape, y_train.shape
# Out:
# ((584, 1), (584, 1))

# %%
# Variables que podemos aprender

amplitude = tf.Variable(1.0,'amplitude',dtype=np.float64)
length_scale = tf.Variable(1.0,'length',dtype=np.float64)
noise = tf.Variable(1e-6,'noise',dtype=np.float64)

def neg_log_likelihood():
    
kernel = psd_kernels.ExponentiatedQuadratic(
    amplitude=,
    length_scale=tf.Variable(1.0,'length_scale',dtype=np.float64))

#kernel
gp = tfd.GaussianProcess(kernel, x_train)
gp
# Out:
# <tfp.distributions.GaussianProcess 'GaussianProcess/' batch_shape=[] event_shape=[584] dtype=float64>

# %% [markdown]
# ## Que estamos obtimizando?

# %%
with tf.GradientTape() as tape:
    log_likelihood = gp.log_prob(y_train.ravel())
gradients = tape.gradient(-log_likelihood,gp.trainable_variables)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-217-153d2e97d954> in <module>
#       1 with tf.GradientTape() as tape:
#       2     log_likelihood = gp.log_prob(y_train.ravel())
# ----> 3 gradients = tape.gradient(-log_likelihood,gp.trainable_variables)
#
# AttributeError: 'GaussianProcess' object has no attribute 'trainable_variables'

# %%
neg_log_likelihood = -gp.log_prob(y)
optimizer = tf.train.AdamOptimizer().minimize(neg_log_likelihood)

#for i in range(1000):
_, neg_log_likelihood_ = sess.run([optimize, neg_log_likelihood])
#if i % 100 == 0:
#  print("Step {}: NLL = {}".format(i, neg_log_likelihood_))
#print("Final NLL = {}".format(neg_log_likelihood_))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-8e80b6beaa94> in <module>
#       1 neg_log_likelihood = -gp.log_prob(y)
# ----> 2 optimize = tf.train.AdamOptimizer().minimize(neg_log_likelihood)
#       3
#       4 #for i in range(1000):
#       5 _, neg_log_likelihood_ = sess.run([optimize, neg_log_likelihood])
#
# AttributeError: module 'tensorflow._api.v2.train' has no attribute 'AdamOptimizer'

# %% [markdown]
# ## Actividad:
#
# Encuentra el mejor modelo!
#
# Analiza los datos, utiliza difefrentes combinaciones de kerneles
